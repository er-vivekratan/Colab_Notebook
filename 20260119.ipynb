# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("https://drive.google.com/uc?export=download&id=1C-I0ER0kAyvpvLcE75QcDVRAiOovreMZ")
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values
model = KNeighborsClassifier()
model.fit(X,y)
df
# Out:
#     diameter  weight FruitName
# 0        3.0      30    Banana
# 1        6.0     100     Apple
# 2        6.1      95     Apple
# 3        3.2      35    Banana
# 4        5.5      80     Apple
# 5        7.1     120    Banana
# 6        2.5      60    Banana
# 7        2.3     100    Banana
# 8        4.8      70     Apple
# 9        4.8      79     Apple
# 10       5.8     120     Apple
# 11       2.6      85    Banana
# 12       6.0     110     Apple
# 13       6.3      95     Apple
# 14       3.0      40    Banana
# 15       3.5      25    Banana
# 16       5.5     100     Apple
# 17       7.5     120     Apple
# 18       2.5      50    Banana
# 19       2.7      40    Banana
# 20       4.8      90     Apple
# 21       5.8      90     Apple

# %%
new_sample1=[3.5, 25]
new_sample2=[6,65]
model.predict([new_sample1,new_sample2])
# Out:
# array(['Banana', 'Apple'], dtype=object)
